# %%
# !pip install fastapi uvicorn pyngrok nest-asyncio transformers==4.52.4 torch sentencepiece spacy datasets accelerate
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 61.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3fcb5b32-f52e-4f0b-9183-37b0edf8f556" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3fcb5b32-f52e-4f0b-9183-37b0edf8f556">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
from google.colab import userdata

try:
    # 1. Fetch using your exact secret panel key name
    token = userdata.get('NGROK_AUTHTOKEN')

    # 2. Match the environment variable token injection name exactly with main.py
    print("Launching server with inline environment injection...")
    # !NGROK_AUTHTOKEN={token} python main.py

except userdata.SecretNotFoundError:
    print("❌ Error: 'NGROK_AUTHTOKEN' was not found in your Colab secrets manager panel.")
    print("Please check your key icon on the left panel and turn on Notebook access.")
# Out:
# Launching server with inline environment injection...
# .config
# main.py
# email_summarizer_pipeline.py
# summaries.db
# .ipynb_checkpoints
# __pycache__
# sample_data
# True
# 2026-06-12 04:47:23.537026: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-06-12 04:47:23.634054: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Transformers version:
# 4.52.4
# True
# Loading summarizer...
# Device set to use cpu
# Loading intent classifier...
# Device set to use cpu
# Loading spaCy NER...
# All models loaded.
# Running pipeline on sample email...
#
# ...
